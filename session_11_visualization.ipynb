# %% [markdown]
# # Session 11: Data Visualization with Matplotlib
#
# How to use this notebook:
# - Run cells from top to bottom (Shift+Enter).
# - Don't worry if you make mistakes - errors are part of learning.
# - Cells labeled "Your code here" are for you to edit.
# - Text that starts with hashmarks '#' are not part of the code.
#
# In this session, you'll learn:
# - Creating line plots, bar charts, and scatter plots
# - Customizing colors, labels, and titles
# - Combining multiple charts into subplots
# - Building a personal finance dashboard
#
# **Duration:** 30 minutes

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Enable inline plotting
# %matplotlib inline

# %% [markdown]
# ## Part 1: Basic Line Plot (5 minutes)
#
# Line plots are ideal for showing how a value changes over time.

# %%
# Simple line plot
months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun']
sales = [15000, 18000, 22000, 20000, 25000, 30000]

plt.figure(figsize=(10, 6))
plt.plot(months, sales, marker='o', linewidth=2, color='blue')
plt.title('Monthly Sales', fontsize=16)
plt.xlabel('Month', fontsize=12)
plt.ylabel('Sales ($)', fontsize=12)
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Part 2: Bar Chart (5 minutes)
#
# Bar charts are ideal for comparing values across categories.

# %%
# Bar chart
products = ['Laptop', 'Mouse', 'Keyboard', 'Monitor', 'Headphones']
quantities = [45, 120, 85, 30, 95]

plt.figure(figsize=(10, 6))
plt.bar(products, quantities, color=['#FF6B6B', '#4ECDC4', '#45B7D1', '#FFA07A', '#98D8C8'])
plt.title('Product Sales by Quantity', fontsize=16)
plt.xlabel('Product', fontsize=12)
plt.ylabel('Quantity Sold', fontsize=12)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Part 3: Scatter Plot (5 minutes)
#
# Scatter plots are ideal for showing the relationship between two numeric variables.

# %%
# Scatter plot
study_hours = [1, 2, 3, 4, 5, 6, 7, 8]
test_scores = [65, 70, 75, 78, 82, 85, 88, 90]

plt.figure(figsize=(10, 6))
plt.scatter(study_hours, test_scores, s=100, alpha=0.6, c='green')
plt.title('Study Hours vs Test Scores', fontsize=16)
plt.xlabel('Hours Studied', fontsize=12)
plt.ylabel('Test Score', fontsize=12)
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Part 4: Multiple Plots (5 minutes)
#
# `plt.subplots()` lets you place several charts in a grid on one figure.

# %%
# Subplots
fig, axes = plt.subplots(2, 2, figsize=(12, 10))

# Plot 1: Line
axes[0, 0].plot(months, sales, marker='o')
axes[0, 0].set_title('Sales Trend')
axes[0, 0].grid(True, alpha=0.3)

# Plot 2: Bar
axes[0, 1].bar(products, quantities, color='skyblue')
axes[0, 1].set_title('Product Quantities')
axes[0, 1].tick_params(axis='x', rotation=45)

# Plot 3: Scatter
axes[1, 0].scatter(study_hours, test_scores, c='red', alpha=0.6)
axes[1, 0].set_title('Study vs Scores')
axes[1, 0].grid(True, alpha=0.3)

# Plot 4: Histogram
data = np.random.normal(100, 15, 1000)
axes[1, 1].hist(data, bins=30, color='purple', alpha=0.7)
axes[1, 1].set_title('Distribution')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Part 5: Practical Project - Personal Finance Dashboard (10 minutes)
#
# Let's combine everything from this session into a single multi-chart dashboard.

# %%
# Create personal finance data
expense_categories = ['Rent', 'Food', 'Transport', 'Entertainment', 'Utilities', 'Savings']
monthly_amounts = [1200, 400, 200, 150, 100, 450]

income = 2500
total_expenses = sum(monthly_amounts)
savings_rate = (monthly_amounts[-1] / income) * 100

# Create visualization dashboard
fig = plt.figure(figsize=(15, 10))

# Pie chart
ax1 = plt.subplot(2, 2, 1)
colors = ['#FF6B6B', '#4ECDC4', '#45B7D1', '#FFA07A', '#98D8C8', '#90EE90']
ax1.pie(monthly_amounts, labels=expense_categories, autopct='%1.1f%%', colors=colors)
ax1.set_title('Expense Breakdown', fontsize=14, fontweight='bold')

# Bar chart
ax2 = plt.subplot(2, 2, 2)
ax2.bar(expense_categories, monthly_amounts, color=colors)
ax2.set_title('Monthly Expenses by Category', fontsize=14, fontweight='bold')
ax2.set_ylabel('Amount ($)')
ax2.tick_params(axis='x', rotation=45)

# Income vs Expenses
ax3 = plt.subplot(2, 2, 3)
categories = ['Income', 'Expenses', 'Savings']
values = [income, total_expenses, monthly_amounts[-1]]
ax3.bar(categories, values, color=['green', 'red', 'blue'])
ax3.set_title('Income vs Expenses', fontsize=14, fontweight='bold')
ax3.set_ylabel('Amount ($)')

# Summary text
ax4 = plt.subplot(2, 2, 4)
ax4.axis('off')
summary_text = f"""
MONTHLY FINANCIAL SUMMARY

Total Income: ${income:,.2f}
Total Expenses: ${total_expenses:,.2f}
Net Savings: ${income - total_expenses:,.2f}

Savings Rate: {savings_rate:.1f}%

Largest Expense: {expense_categories[monthly_amounts.index(max(monthly_amounts))]}
Amount: ${max(monthly_amounts):,.2f}
"""
ax4.text(0.1, 0.5, summary_text, fontsize=12, family='monospace',
         verticalalignment='center')

plt.tight_layout()
plt.savefig('finance_dashboard.png', dpi=300, bbox_inches='tight')
plt.show()

print('Dashboard saved as finance_dashboard.png')

# %% [markdown]
# ### Your Turn
#
# Create visualizations for your own data - fitness tracking, spending habits, or study time.

# %%
# Your visualization code here

# %% [markdown]
# ### Bonus Challenge
#
# Extend the finance dashboard (or your own visualization) with:
# 1. A horizontal bar chart (`plt.barh()`) instead of vertical
# 2. A second `axhline()` or `axvline()` marking a target/goal value
# 3. A custom color palette applied consistently across all charts

# %%
# Your bonus code here

# %% [markdown]
# ## Summary
#
# Today you learned:
# - ✓ Create line, bar, and scatter plots
# - ✓ Customize colors, labels, and titles
# - ✓ Create subplots for multiple visualizations
# - ✓ Save figures as images
# - ✓ Build a complete dashboard
#
# **Next session:** We'll combine everything into a full capstone project!
#
# ### Key Takeaways
# - Line plot: `plt.plot(x, y)`
# - Bar chart: `plt.bar(categories, values)`
# - Scatter plot: `plt.scatter(x, y)`
# - Multiple charts on one figure: `fig, axes = plt.subplots(rows, cols)`
# - Save a figure: `plt.savefig('name.png', dpi=300, bbox_inches='tight')`
